# %% [markdown]
# <a href="https://colab.research.google.com/github/Skyline-9/Visionary-Vids/blob/main/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Skyline-9/Visionary-Vids.git

# %%
# %cd Visionary-Vids/
# !pip install -r environment/requirements.txt
# !cd datasets && bash download_tvsum.sh && cd ..

# %%
# !python launch.py configs/tvsum/umt_small_500e_tvsum_bk.py
# Out:
# [2023-04-28 03:22:16 INFO]: Environment info:
# ----------------------  ------------------------------------------------------------------
# System                  Linux
# Python                  3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0]
# CUDA_HOME               /usr/local/cuda
# TORCH_CUDA_ARCH_LIST    <not-found>
# NVCC                    Build cuda_11.8.r11.8/compiler.31833905_0
# GPU 0                   Tesla T4
# PyTorch                 2.0.0+cu118 @ /usr/local/lib/python3.10/dist-packages/torch
# PyTorch debug build     False
# torchvision             0.15.1+cu118 @ /usr/local/lib/python3.10/dist-packages/torchvision
# torchvision arch flags  sm_35, sm_50, sm_60, sm_70, sm_75, sm_80, sm_86
# nncore                  0.3.6
# numpy                   1.22.4
# PIL                     8.4.0
# cv2                     4.7.0
# ----------------------  ------------------------------------------------------------------
# PyTorch built with:
#   - GCC 9.3
# ...

# %%
# !python launch.py configs/tvsum/umt_small_500e_tvsum_bk.py --checkpoint /content/Visionary-Vids/work_dirs/umt_small_500e_tvsum_bk/epoch_500.pth --eval
# Out:
# [2023-04-28 03:36:29 INFO]: Environment info:
# ----------------------  ------------------------------------------------------------------
# System                  Linux
# Python                  3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0]
# CUDA_HOME               /usr/local/cuda
# TORCH_CUDA_ARCH_LIST    <not-found>
# NVCC                    Build cuda_11.8.r11.8/compiler.31833905_0
# GPU 0                   Tesla T4
# PyTorch                 2.0.0+cu118 @ /usr/local/lib/python3.10/dist-packages/torch
# PyTorch debug build     False
# torchvision             0.15.1+cu118 @ /usr/local/lib/python3.10/dist-packages/torchvision
# torchvision arch flags  sm_35, sm_50, sm_60, sm_70, sm_75, sm_80, sm_86
# nncore                  0.3.6
# numpy                   1.22.4
# PIL                     8.4.0
# cv2                     4.7.0
# ----------------------  ------------------------------------------------------------------
# PyTorch built with:
#   - GCC 9.3
# ...
